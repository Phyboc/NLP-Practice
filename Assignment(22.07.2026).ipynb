# %% [markdown]
# Lab Assignment by Sivasubramani K J [CB.SC.U4CSE24752]
#
# Lab Assignment:
# 1.Write a set of sentences about the foods that you like.
# conclude what type of foodie you are.
#
# "I like Aloo Paratha with yogurt. I also like Bun Parotha with veg kuruma. I love exploring foods of all tastes, but only veg."
#
# (solve by hand and demonstrate TD-IDF step by step)
#
#
# (Implement using NLTK to demonstrate TD-IDF)

# %%
import nltk
import string
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer


corpus = [
    "I like Aloo Paratha with yogurt.",
    "I also like Bun Parotha with veg kuruma.",
    "I love exploring foods of all tastes, but only veg."
]

stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = text.lower().translate(str.maketrans("", "", string.punctuation))
    tokens = word_tokenize(text)
    cleaned_tokens = [word for word in tokens if word not in stop_words]
    return " ".join(cleaned_tokens)

cleaned_corpus = [preprocess(doc) for doc in corpus]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(cleaned_corpus)

df_tfidf = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out(),
    index=[f"Doc {i+1}" for i in range(len(corpus))]
)

print(df_tfidf.round(3))
# Out:
#         aloo  also   bun  exploring  foods  kuruma   like   love  paratha  \
# Doc 1  0.529  0.00  0.00      0.000  0.000    0.00  0.402  0.000    0.529
# Doc 2  0.000  0.44  0.44      0.000  0.000    0.44  0.335  0.000    0.000
# Doc 3  0.000  0.00  0.00      0.467  0.467    0.00  0.000  0.467    0.000
#
#        parotha  tastes    veg  yogurt
# Doc 1     0.00   0.000  0.000   0.529
# Doc 2     0.44   0.000  0.335   0.000
# Doc 3     0.00   0.467  0.355   0.000

# %% [markdown]
# 2. Write a set of sentences about the foods that you like.
# conclude what type of foodie you are.
# 	(solve by hand and demonstrate N-gram step by step)
# 	(Implement using NLTK to demonstrate N-gram)

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.corpus import stopwords


text = "I love exploring foods of all tastes, but only veg."

text_clean = text.lower().translate(str.maketrans("", "", string.punctuation))
tokens = word_tokenize(text_clean)

unigrams = list(ngrams(tokens, 1))
bigrams  = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))

print("--- TOKENS ---")
print(tokens)

print("\n--- BIGRAMS (N=2) ---")
print(bigrams)

print("\n--- TRIGRAMS (N=3) ---")
print(trigrams)
# Out:
# --- TOKENS ---
# ['i', 'love', 'exploring', 'foods', 'of', 'all', 'tastes', 'but', 'only', 'veg']
#
# --- BIGRAMS (N=2) ---
# [('i', 'love'), ('love', 'exploring'), ('exploring', 'foods'), ('foods', 'of'), ('of', 'all'), ('all', 'tastes'), ('tastes', 'but'), ('but', 'only'), ('only', 'veg')]
#
# --- TRIGRAMS (N=3) ---
# [('i', 'love', 'exploring'), ('love', 'exploring', 'foods'), ('exploring', 'foods', 'of'), ('foods', 'of', 'all'), ('of', 'all', 'tastes'), ('all', 'tastes', 'but'), ('tastes', 'but', 'only'), ('but', 'only', 'veg')]
